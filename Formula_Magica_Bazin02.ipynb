# %% [markdown]
# <a href="https://github/cacciella/Curso-em-Video/blob/master/Formula_Magica_Bazin02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
sns.set() # notebook
pd.options.mode.chained_assignment = None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
  #return pd.to_numeric(value.replace(',','.').replace('.',''))

# %%
# mapeando colunas que possuem valor percentuais
# convs = {1: convert_per, 2: convert_per, 3: convert_per, 4: convert_per, 5: convert_per, 6: convert_per, 7: convert_per, 8: convert_per, 9: convert_per, 10: convert_per, 11: convert_per, 12: convert_per, 13: convert_per, 14: convert_per, 15: convert_per, 16: convert_per, 17: convert_per, 18: convert_per, 19: convert_per, 20: convert_per, 21: convert_per, 22: convert_per, 23: convert_per, 24: convert_per, 25: convert_per, 26: convert_per, 27: convert_per, 28: convert_per, 29: convert_per}

# %%
#start = datetime.now()
#df = pd.read_csv('/content/drive/MyDrive/Dados/statusinvest_set23.csv', decimal = ',', thousands = '.', index_col = 'Papel', converters = convs)[0]
#print(datetime.now() - start)

df = pd.read_csv('/content/drive/MyDrive/Dados/statusinvest_set23_02.csv')
#print(datetime.now() - start)

# %% [markdown]
# - Para ler um arquivo CSV, tem que eliminar virgulas nos valores numéricos e separação decimal somente com pontos.
#
#  somente letras sem pontos de abreviação

# %%
df.shape
# Out:
# (620, 30)

# %%
df.columns
# Out:
# Index(['__PAPEL__', 'PRECO', 'DY', 'P/L', 'P/VP', 'P/ATIVOS', 'MARGEM BRUTA',
#        'MARGEM EBIT', 'MARG. LIQUIDA', 'P/EBIT', 'EV/EBIT',
#        'DIVIDA LIQUIDA / EBIT', 'DIV LIQ / PATRI', 'PSR', 'P/CAP GIRO',
#        'P AT CIR LIQ', 'LIQ CORRENTE', 'ROE', 'ROA', 'ROIC',
#        'PATRIMONIO / ATIVOS', 'PASSIVOS / ATIVOS', 'GIRO ATIVOS',
#        'CAGR RECEITAS 5 ANOS', 'CAGR LUCROS 5 ANOS', 'LIQUIDEZ MEDIA DIARIA',
#        'VPA', 'LPA', 'PEG Ratio', 'VALOR DE MERCADO'],
#       dtype='object')

# %%
df.dtypes
# Out:
# __PAPEL__                 object
# PRECO                    float64
# DY                       float64
# P/L                      float64
# P/VP                     float64
# P/ATIVOS                 float64
# MARGEM BRUTA             float64
# MARGEM EBIT              float64
# MARG. LIQUIDA            float64
# P/EBIT                   float64
# EV/EBIT                  float64
# DIVIDA LIQUIDA / EBIT    float64
# DIV LIQ / PATRI          float64
# PSR                      float64
# P/CAP GIRO               float64
# P AT CIR LIQ             float64
# LIQ CORRENTE             float64
# ROE                      float64
# ROA                      float64
# ROIC                     float64
# PATRIMONIO / ATIVOS      float64
# PASSIVOS / ATIVOS        float64
# GIRO ATIVOS              float64
# CAGR RECEITAS 5 ANOS     float64
# CAGR LUCROS 5 ANOS       float64
# LIQUIDEZ MEDIA DIARIA    float64
# VPA                      float64
# LPA                      float64
# ...

# %%
df.describe()
# Out:
#          PRECO      DY      P/L      P/VP   P/ATIVOS  MARGEM BRUTA  \
# count   620.00  335.00   620.00    617.00     620.00        589.00
# mean     54.42   15.36    86.66    199.62    4463.27        -15.04
# std     494.14  153.19  1983.05   6144.54  111051.46        452.33
# min       0.00    0.10 -4141.29 -30200.65       0.00      -4128.22
# 25%       4.79    2.00     0.00      0.54       0.16         19.73
# 50%      12.16    3.95     6.63      1.10       0.42         31.52
# 75%      26.00    6.83    13.49      2.09       0.88         46.97
# max   11091.73 2762.62 48754.69 149535.60 2765162.30        101.46
#
#        MARGEM EBIT  MARG. LIQUIDA  P/EBIT  EV/EBIT  ...  PATRIMONIO / ATIVOS  \
# count       589.00         589.00  620.00   613.00  ...               620.00
# mean          3.98          51.06   19.50    15.60  ...                -0.34
# std        1023.40        1180.62  189.32   183.77  ...                 6.38
# ...

# %%
df
# Out:
#     __PAPEL__  PRECO   DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0       AALR3   8.85  NaN  -3.67  1.22      0.42         30.29        -1.09
# 1       ABCB4  20.64 7.67   5.88  0.85      0.09         31.62        25.25
# 2       ABEV3  13.49 5.65  14.90  2.50      1.60         49.95        21.50
# 3       ADHM3   1.56  NaN  -4.09 -1.29    105.12        100.00    -13548.48
# 4       AERI3   0.93  NaN  -6.54  0.83      0.22         13.03         9.37
# ..        ...    ...  ...    ...   ...       ...           ...          ...
# 615     WIZC3   5.44 8.21   8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16   8.03  1.39      0.96         12.56         7.05
# 617     WLMM4  39.40 2.20  12.68  2.20      1.52         12.56         7.05
# 618     YDUQ3  20.51  NaN  56.98  2.00      0.65         58.53        16.35
# 619     ZAMP3   6.36  NaN -14.87  1.21      0.41         64.96         2.25
#
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.head()
# Out:
#   __PAPEL__  PRECO   DY   P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0     AALR3   8.85  NaN -3.67  1.22      0.42         30.29        -1.09
# 1     ABCB4  20.64 7.67  5.88  0.85      0.09         31.62        25.25
# 2     ABEV3  13.49 5.65 14.90  2.50      1.60         49.95        21.50
# 3     ADHM3   1.56  NaN -4.09 -1.29    105.12        100.00    -13548.48
# 4     AERI3   0.93  NaN -6.54  0.83      0.22         13.03         9.37
#
#    MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS  PASSIVOS / ATIVOS  \
# 0         -25.30  -85.28  ...                 0.34               0.65
# 1          19.35    4.51  ...                 0.10               0.90
# 2          17.26   11.96  ...                 0.64               0.35
# 3      -18860.61   -5.69  ...               -81.72              82.72
# 4          -3.59    2.51  ...                 0.27               0.73
#
#    GIRO ATIVOS  CAGR RECEITAS 5 ANOS  CAGR LUCROS 5 ANOS  \
# ...

# %%
# Selecionando algumas linhas e colunas ( visualizando o meio da tabela )
df.loc[:, ['EV/EBIT', 'DIVIDA LIQUIDA / EBIT', 'PSR', 'P/CAP GIRO', 'LIQ CORRENTE', 'ROE', 'ROIC']]
# Out:
#      EV/EBIT  DIVIDA LIQUIDA / EBIT    PSR  P/CAP GIRO  LIQ CORRENTE    ROE  \
# 0    -160.99                 -72.55   0.93       -3.27          0.55 -33.11
# 1       4.52                    NaN   1.14        3.73          1.50  14.50
# 2      11.44                  -0.47   2.57     1051.12          1.01  16.78
# 3      -5.69                   0.00 770.90       -1.43          0.00 -31.47
# 4       5.97                   3.38   0.24        0.92          1.63 -12.65
# ..       ...                    ...    ...         ...           ...    ...
# 615     2.53                   0.12   0.87       -7.99          0.84  25.32
# 616     7.70                  -0.01   0.41        2.62          2.48  17.35
# 617     7.70                  -0.01   0.65        4.13          2.48  17.35
# 618    13.39                   5.37   1.29        6.80          1.56   3.51
# 619    27.37                   8.64   0.44       12.43          1.18  -8.15
#
#      ROIC
# 0   -1.98
# 1     NaN
# 2   18.20
# ...

# %%
#  linha x coluna ( visualizando o meio da tabela )
df.iloc[1:4, 10:21]
# Out:
#    EV/EBIT  DIVIDA LIQUIDA / EBIT  DIV LIQ / PATRI    PSR  P/CAP GIRO  \
# 1     4.52                    NaN              NaN   1.14        3.73
# 2    11.44                  -0.47            -0.10   2.57     1051.12
# 3    -5.69                   0.00              NaN 770.90       -1.43
#
#    P AT CIR LIQ  LIQ CORRENTE    ROE      ROA  ROIC  PATRIMONIO / ATIVOS
# 1         -0.09          1.50  14.50     1.45   NaN                 0.10
# 2         -2.15          1.01  16.78    10.71 18.20                 0.64
# 3       -116.16          0.00 -31.47 -2571.90 22.61               -81.72

# %%
df.tail()
# Out:
#     __PAPEL__  PRECO   DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 615     WIZC3   5.44 8.21   8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16   8.03  1.39      0.96         12.56         7.05
# 617     WLMM4  39.40 2.20  12.68  2.20      1.52         12.56         7.05
# 618     YDUQ3  20.51  NaN  56.98  2.00      0.65         58.53        16.35
# 619     ZAMP3   6.36  NaN -14.87  1.21      0.41         64.96         2.25
#
#      MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS  PASSIVOS / ATIVOS  \
# 615          10.49    2.34  ...                 0.17               0.59
# 616           5.11    5.82  ...                 0.69               0.31
# 617           5.11    9.19  ...                 0.69               0.31
# 618           2.27    7.90  ...                 0.32               0.68
# 619          -2.95   19.50  ...                 0.34               0.66
#
#      GIRO ATIVOS  CAGR RECEITAS 5 ANOS  CAGR LUCROS 5 ANOS  \
# ...

# %%
# filtrando empresas com EV maior que 50 Milhoes
#fundamentus = fundamentus[fundamentus['Patrim. Líq'] > 50000000]
#fundamentus.describe()

# %%
# primeiro visualizando
df [df['VALOR DE MERCADO'] > 50000000]
# Out:
#     __PAPEL__  PRECO   DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0       AALR3   8.85  NaN  -3.67  1.22      0.42         30.29        -1.09
# 1       ABCB4  20.64 7.67   5.88  0.85      0.09         31.62        25.25
# 2       ABEV3  13.49 5.65  14.90  2.50      1.60         49.95        21.50
# 4       AERI3   0.93  NaN  -6.54  0.83      0.22         13.03         9.37
# 5       AESB3  11.56  NaN  47.46  1.56      0.35         34.55        27.40
# ..        ...    ...  ...    ...   ...       ...           ...          ...
# 615     WIZC3   5.44 8.21   8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16   8.03  1.39      0.96         12.56         7.05
# 617     WLMM4  39.40 2.20  12.68  2.20      1.52         12.56         7.05
# 618     YDUQ3  20.51  NaN  56.98  2.00      0.65         58.53        16.35
# 619     ZAMP3   6.36  NaN -14.87  1.21      0.41         64.96         2.25
#
# ...

# %%
# filtrando por VALOR DE MERCADO
df = df [df['VALOR DE MERCADO'] > 50000000]

# %%
df
# Out:
#     __PAPEL__  PRECO   DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0       AALR3   8.85  NaN  -3.67  1.22      0.42         30.29        -1.09
# 1       ABCB4  20.64 7.67   5.88  0.85      0.09         31.62        25.25
# 2       ABEV3  13.49 5.65  14.90  2.50      1.60         49.95        21.50
# 4       AERI3   0.93  NaN  -6.54  0.83      0.22         13.03         9.37
# 5       AESB3  11.56  NaN  47.46  1.56      0.35         34.55        27.40
# ..        ...    ...  ...    ...   ...       ...           ...          ...
# 615     WIZC3   5.44 8.21   8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16   8.03  1.39      0.96         12.56         7.05
# 617     WLMM4  39.40 2.20  12.68  2.20      1.52         12.56         7.05
# 618     YDUQ3  20.51  NaN  56.98  2.00      0.65         58.53        16.35
# 619     ZAMP3   6.36  NaN -14.87  1.21      0.41         64.96         2.25
#
# ...

# %%
# filtrando por PL (quanto menor melhor)
# quantos anos levaria para retornar o capital investido
# neste caso abaixo de 15 anos
df [df['P/L'] < 15]
# Out:
#     __PAPEL__  PRECO   DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0       AALR3   8.85  NaN  -3.67  1.22      0.42         30.29        -1.09
# 1       ABCB4  20.64 7.67   5.88  0.85      0.09         31.62        25.25
# 2       ABEV3  13.49 5.65  14.90  2.50      1.60         49.95        21.50
# 4       AERI3   0.93  NaN  -6.54  0.83      0.22         13.03         9.37
# 6       AFLT3   8.07 3.09  13.66  1.98      1.74         59.73        49.97
# ..        ...    ...  ...    ...   ...       ...           ...          ...
# 612     WEST3   1.49  NaN  -2.77  0.56      0.41         42.46       -35.85
# 615     WIZC3   5.44 8.21   8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16   8.03  1.39      0.96         12.56         7.05
# 617     WLMM4  39.40 2.20  12.68  2.20      1.52         12.56         7.05
# 619     ZAMP3   6.36  NaN -14.87  1.21      0.41         64.96         2.25
#
# ...

# %%
# neste caso abaixo de 10 anos
df [df['P/L'] < 10]
# Out:
#     __PAPEL__  PRECO   DY     P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 0       AALR3   8.85  NaN   -3.67  1.22      0.42         30.29        -1.09
# 1       ABCB4  20.64 7.67    5.88  0.85      0.09         31.62        25.25
# 4       AERI3   0.93  NaN   -6.54  0.83      0.22         13.03         9.37
# 8       AGXY3   4.78 0.83   -4.16  0.77      0.09         12.38         3.90
# 9       AHEB3  18.95  NaN    2.16 18.88      0.44         35.19        21.45
# ..        ...    ...  ...     ...   ...       ...           ...          ...
# 609     VVAR4  95.68  NaN -196.92 49.34      6.90         30.67         1.83
# 612     WEST3   1.49  NaN   -2.77  0.56      0.41         42.46       -35.85
# 615     WIZC3   5.44 8.21    8.25  2.09      0.37         58.20        36.98
# 616     WLMM3  25.00 3.16    8.03  1.39      0.96         12.56         7.05
# 619     ZAMP3   6.36  NaN  -14.87  1.21      0.41         64.96         2.25
#
# ...

# %%
# filtrando e salvando PL abaixo de 10 anos
df = df [df['P/L'] < 10]

# %%
# Dividend Yield (quanto maior melhor)
df [df['DY'] > 4]
# Out:
#     __PAPEL__  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 1       ABCB4  20.64  7.67 5.88  0.85      0.09         31.62        25.25
# 12      ALLD3   6.57  5.54 9.49  0.39      0.17         13.77         3.60
# 36      AURE3  13.99 10.82 4.48  0.94      0.42         21.03        27.60
# 46      BAZA3  84.61  6.51 3.67  0.84      0.11         29.18        53.10
# 47      BBAS3  47.95  9.74 4.16  0.83      0.07         32.03        16.16
# ..        ...    ...   ...  ...   ...       ...           ...          ...
# 580     TRPL4  24.06  4.45 6.64  0.90      0.46         60.07        64.90
# 583     TUPY3  28.31  4.25 8.94  1.30      0.41         17.79         6.67
# 588     UNIP3  75.72  8.36 9.96  2.99      1.33         38.90        24.82
# 594     VALE3  69.36  5.86 5.49  1.67      0.71         39.09        30.44
# 615     WIZC3   5.44  8.21 8.25  2.09      0.37         58.20        36.98
#
# ...

# %%
# salvando
df = df [df['DY'] > 4]

# %%
# LPA (lucro por ação) qto. maior melhor
df [df['DY'] > 4]
# Out:
#     __PAPEL__  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 1       ABCB4  20.64  7.67 5.88  0.85      0.09         31.62        25.25
# 12      ALLD3   6.57  5.54 9.49  0.39      0.17         13.77         3.60
# 36      AURE3  13.99 10.82 4.48  0.94      0.42         21.03        27.60
# 46      BAZA3  84.61  6.51 3.67  0.84      0.11         29.18        53.10
# 47      BBAS3  47.95  9.74 4.16  0.83      0.07         32.03        16.16
# ..        ...    ...   ...  ...   ...       ...           ...          ...
# 580     TRPL4  24.06  4.45 6.64  0.90      0.46         60.07        64.90
# 583     TUPY3  28.31  4.25 8.94  1.30      0.41         17.79         6.67
# 588     UNIP3  75.72  8.36 9.96  2.99      1.33         38.90        24.82
# 594     VALE3  69.36  5.86 5.49  1.67      0.71         39.09        30.44
# 615     WIZC3   5.44  8.21 8.25  2.09      0.37         58.20        36.98
#
# ...

# %%
df = df [df['DY'] > 4]

# %%
# ROE retorno do investimento,  qto. maior melhor, ideal acima de 10%
df [df['ROE'] > 9]
# Out:
#     __PAPEL__  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 1       ABCB4  20.64  7.67 5.88  0.85      0.09         31.62        25.25
# 36      AURE3  13.99 10.82 4.48  0.94      0.42         21.03        27.60
# 46      BAZA3  84.61  6.51 3.67  0.84      0.11         29.18        53.10
# 47      BBAS3  47.95  9.74 4.16  0.83      0.07         32.03        16.16
# 48      BBDC3  13.16  7.02 8.53  0.83      0.07         31.88         6.19
# ..        ...    ...   ...  ...   ...       ...           ...          ...
# 580     TRPL4  24.06  4.45 6.64  0.90      0.46         60.07        64.90
# 583     TUPY3  28.31  4.25 8.94  1.30      0.41         17.79         6.67
# 588     UNIP3  75.72  8.36 9.96  2.99      1.33         38.90        24.82
# 594     VALE3  69.36  5.86 5.49  1.67      0.71         39.09        30.44
# 615     WIZC3   5.44  8.21 8.25  2.09      0.37         58.20        36.98
#
# ...

# %%
df [df['ROE'] > 10]
# Out:
#     __PAPEL__  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 1       ABCB4  20.64  7.67 5.88  0.85      0.09         31.62        25.25
# 36      AURE3  13.99 10.82 4.48  0.94      0.42         21.03        27.60
# 46      BAZA3  84.61  6.51 3.67  0.84      0.11         29.18        53.10
# 47      BBAS3  47.95  9.74 4.16  0.83      0.07         32.03        16.16
# 51      BBSE3  31.78 10.99 8.83  7.09      3.73           NaN          NaN
# ..        ...    ...   ...  ...   ...       ...           ...          ...
# 580     TRPL4  24.06  4.45 6.64  0.90      0.46         60.07        64.90
# 583     TUPY3  28.31  4.25 8.94  1.30      0.41         17.79         6.67
# 588     UNIP3  75.72  8.36 9.96  2.99      1.33         38.90        24.82
# 594     VALE3  69.36  5.86 5.49  1.67      0.71         39.09        30.44
# 615     WIZC3   5.44  8.21 8.25  2.09      0.37         58.20        36.98
#
# ...

# %%
df = df [df['ROE'] > 10]

# %%
df.max()
# Out:
# __PAPEL__                         WIZC3
# PRECO                            295.05
# DY                                27.02
# P/L                                9.96
# P/VP                               7.09
# P/ATIVOS                           3.73
# MARGEM BRUTA                      89.64
# MARGEM EBIT                      199.77
# MARG. LIQUIDA                    169.98
# P/EBIT                            15.00
# EV/EBIT                           10.81
# DIVIDA LIQUIDA / EBIT              3.80
# DIV LIQ / PATRI                    2.57
# PSR                               11.69
# P/CAP GIRO                        44.53
# P AT CIR LIQ                      -0.06
# LIQ CORRENTE                      25.52
# ROE                               80.32
# ROA                               42.31
# ROIC                              42.77
# PATRIMONIO / ATIVOS                0.99
# PASSIVOS / ATIVOS                  0.95
# GIRO ATIVOS                        1.85
# ...

# %%
# contar quantos registros não informados (nan)
df.dropna().count()
# Out:
# __PAPEL__                57
# PRECO                    57
# DY                       57
# P/L                      57
# P/VP                     57
# P/ATIVOS                 57
# MARGEM BRUTA             57
# MARGEM EBIT              57
# MARG. LIQUIDA            57
# P/EBIT                   57
# EV/EBIT                  57
# DIVIDA LIQUIDA / EBIT    57
# DIV LIQ / PATRI          57
# PSR                      57
# P/CAP GIRO               57
# P AT CIR LIQ             57
# LIQ CORRENTE             57
# ROE                      57
# ROA                      57
# ROIC                     57
# PATRIMONIO / ATIVOS      57
# PASSIVOS / ATIVOS        57
# GIRO ATIVOS              57
# CAGR RECEITAS 5 ANOS     57
# CAGR LUCROS 5 ANOS       57
# LIQUIDEZ MEDIA DIARIA    57
# VPA                      57
# LPA                      57
# PEG Ratio                57
# VALOR DE MERCADO         57
# dtype: int64

# %%
sns.boxplot(x=df['PRECO'],orient='Vertical')
# Out:
# <Axes: xlabel='PRECO'>

# %%
df [df['PRECO'] < 45]
# Out:
#     __PAPEL__  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# 1       ABCB4  20.64  7.67 5.88  0.85      0.09         31.62        25.25
# 36      AURE3  13.99 10.82 4.48  0.94      0.42         21.03        27.60
# 51      BBSE3  31.78 10.99 8.83  7.09      3.73           NaN          NaN
# 56      BEES3   8.71  7.24 8.33  1.34      0.07         26.39         8.82
# 57      BEES4  10.00  6.29 9.58  1.55      0.08         26.39         8.82
# ..        ...    ...   ...  ...   ...       ...           ...          ...
# 554     TASA4  16.67  8.53 6.72  1.96      1.01         40.56        21.22
# 566     TGMA3  26.64  6.01 9.42  2.17      1.54         20.10        15.04
# 580     TRPL4  24.06  4.45 6.64  0.90      0.46         60.07        64.90
# 583     TUPY3  28.31  4.25 8.94  1.30      0.41         17.79         6.67
# 615     WIZC3   5.44  8.21 8.25  2.09      0.37         58.20        36.98
#
# ...

# %%
df = df [df['PRECO'] < 45]

# %%
sns.boxplot(x=df['PRECO'],orient='Vertical')
# Out:
# <Axes: xlabel='PRECO'>

# %%
# Selecionando algumas linhas e colunas
df.loc[36:57, ['PRECO', 'P/L']]
# Out:
#     PRECO  P/L
# 36  13.99 4.48
# 51  31.78 8.83
# 56   8.71 8.33
# 57  10.00 9.58

# %%
# Selecionando algumas linhas e colunas
df.loc[:, ['EV/EBIT', 'DIVIDA LIQUIDA / EBIT', 'PSR', 'P/CAP GIRO', 'LIQ CORRENTE', 'ROE', 'ROIC', 'DY']]
# Out:
#      EV/EBIT  DIVIDA LIQUIDA / EBIT  PSR  P/CAP GIRO  LIQ CORRENTE   ROE  \
# 1       4.52                    NaN 1.14        3.73          1.50 14.50
# 36      8.87                   0.27 2.36        2.85          2.12 20.94
# 51      7.72                    NaN  NaN     -529.56          0.98 80.32
# 56      6.29                    NaN 0.54        0.71           NaN 16.14
# 57      6.29                    NaN 0.62        0.82           NaN 16.14
# ..       ...                    ...  ...         ...           ...   ...
# 554     5.12                   0.53 0.96        4.83          1.55 29.14
# 566     7.22                  -0.29 1.14        5.17          2.62 23.01
# 580     7.09                   2.08 2.88        6.19          1.93 13.53
# 583     8.45                   3.03 0.37        1.30          2.06 14.57
# 615     2.53                   0.12 0.87       -7.99          0.84 25.32
#
#      ROIC    DY
# 1     NaN  7.67
# 36   5.22 10.82
# 51    NaN 10.99
# 56    NaN  7.24
# ...

# %%
# analisando os quantile até ter um minimo para descartar
Q1 = df['PRECO'].quantile(0.10)
Q3 = df['PRECO'].quantile(0.97)
print(Q1,Q3)
# Out:
# 0.0 146.51999999999975

# %%
# mostar quantos dados foram eliminados
df[(df['PRECO'] < Q1) | (df['PRECO'] > Q3)].count()
# Out:
# TICKER       16
# PRECO        16
# DY            9
# P/L          16
# P/VP         16
# P/ATIVOS     16
# MARGEM       15
# BRUTA        15
# MARGEM.1     15
# EBIT         16
# MARG         12
# LIQUIDA      14
# P/EBIT       13
# EV/EBIT      14
# DIVIDA       16
# LIQUIDA.1    16
# dtype: int64

# %%
# incorpora os novos dados
df=df[(df['PRECO'] >= Q1) & (df['PRECO'] <= Q3)]

# %%
df['PRECO'].max()
# Out:
# 41.0

# %%
df['PRECO'].min()
# Out:
# 3.48

# %%
df.describe()
# Out:
#        PRECO    DY   P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT  \
# count  74.00 74.00 74.00 74.00     74.00         71.00        71.00
# mean   17.91  8.17  6.39  1.52      0.58         34.75        29.41
# std     9.82  3.92  1.81  1.03      0.51         12.94        34.04
# min     3.48  4.17  2.45  0.37      0.04         -4.09        -3.86
# 25%     9.51  5.98  5.11  0.86      0.31         26.62        12.38
# 50%    16.50  7.36  6.62  1.21      0.50         32.48        21.56
# 75%    24.30  9.96  7.87  1.91      0.77         43.69        32.17
# max    41.00 27.02  9.81  7.09      3.73         60.18       199.77
#
#        MARG. LIQUIDA  P/EBIT  EV/EBIT  ...  PATRIMONIO / ATIVOS  \
# count          71.00   74.00    74.00  ...                74.00
# mean           21.70    4.55     5.59  ...                 0.40
# std            29.09    2.07     2.51  ...                 0.23
# min             1.26   -2.93    -8.59  ...                 0.05
# ...

# %%
# analisando os quantile até ter um minimo para descartar
Q2 = df['DY'].quantile(0.70)
Q4 = df['DY'].quantile(0.99)
print(Q2,Q4)
# Out:
# 4.0 16.88000000000011

# %%
# mostar quantos dados foram eliminados
df[(df['DY'] < Q2) | (df['DY'] > Q4)].count()
# Out:
# TICKER       180
# PRECO        180
# DY           180
# P/L          180
# P/VP         180
# P/ATIVOS     180
# MARGEM       178
# BRUTA        178
# MARGEM.1     178
# EBIT         180
# MARG         151
# LIQUIDA      166
# P/EBIT       164
# EV/EBIT      178
# DIVIDA       180
# LIQUIDA.1    180
# dtype: int64

# %%
# incorpora os novos dados
df=df[(df['DY'] >= Q2) & (df['DY'] <= Q4)]

# %%
df.describe()
# Out:
#            PRECO         DY        P/L       P/VP   P/ATIVOS      MARGEM  \
# count  85.000000  85.000000  85.000000  85.000000  85.000000   84.000000
# mean   24.376471   6.352941  12.211765   1.576471   0.694118   32.047619
# std    17.180399   2.158625   8.538560   1.706964   0.802133   55.373410
# min     3.000000   4.000000 -22.000000  -7.000000   0.000000 -233.000000
# 25%    11.000000   4.000000   7.000000   1.000000   0.000000   27.750000
# 50%    21.000000   6.000000   9.000000   1.000000   1.000000   38.000000
# 75%    32.000000   8.000000  17.000000   2.000000   1.000000   52.250000
# max    86.000000  14.000000  37.000000   9.000000   5.000000  100.000000
#
#               BRUTA      MARGEM.1         EBIT        MARG      LIQUIDA  \
# count     84.000000     84.000000    85.000000   65.000000    59.000000
# mean     210.416667    222.095238   -28.494118   16.984615    60.694915
# std     1679.004318   1691.514169   236.498496   23.926641   258.756393
# ...

# %%
# inspecionando valores
df.head()
# Out:
#    TICKER  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM  BRUTA  MARGEM.1  EBIT  \
# 5   AGRO3     22   4.0   11     1         1    31.0   22.0      19.0     9
# 32  BALM3     13   7.0   26     1         1    50.0    4.0       3.0    20
# 33  BALM4     10   9.0   20     1         0    50.0    4.0       3.0    15
# 35  BAZA3     37  11.0    3     0         0    38.0   38.0      21.0     2
# 36  BBAS3     34   5.0    6     1         0    14.0    3.0      12.0    20
#
#     MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# 5   13.0      4.0     0.0      2.0     5.0       -1.0
# 32  21.0      3.0     0.0      1.0     2.0       -2.0
# 33  21.0      3.0     0.0      1.0     2.0       -1.0
# 35   2.0      NaN     NaN      1.0     0.0        0.0
# 36  20.0      NaN     NaN      1.0     0.0        0.0

# %%
df.tail()
# Out:
#     TICKER  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM  BRUTA  MARGEM.1  EBIT  \
# 499  UCAS3      4  11.0   18     2         1    40.0   11.0      10.0    17
# 510  VIVT3     49   6.0   17     1         1    50.0   16.0      11.0    11
# 511  VIVT4     49   6.0   17     1         1    50.0   16.0      11.0    11
# 512  VLID3     11   6.0   20     1         0    21.0    6.0       2.0     6
# 520  WIZS3     11   6.0    8     7         3    72.0   52.0      31.0     5
#
#      MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# 499  14.0     -3.0     0.0      2.0     4.0       -3.0
# 510  13.0      1.0     0.0      2.0    42.0       -1.0
# 511  13.0      1.0     0.0      2.0    42.0       -1.0
# 512  12.0      6.0     1.0      0.0     2.0        0.0
# 520   5.0      0.0     0.0      3.0   -21.0       -4.0

# %%
# Selecionando algumas colunas
df.loc[:, ['PRECO', 'DY']]
# Out:
#      PRECO    DY
# 5       22   4.0
# 32      13   7.0
# 33      10   9.0
# 35      37  11.0
# 36      34   5.0
# ..     ...   ...
# 499      4  11.0
# 510     49   6.0
# 511     49   6.0
# 512     11   6.0
# 520     11   6.0
#
# [85 rows x 2 columns]

# %%
# Selecionando algumas linhas
df[15:20]
# Out:
#    TICKER  PRECO   DY  P/L  P/VP  P/ATIVOS  MARGEM  BRUTA  MARGEM.1  EBIT  \
# 80  BRGE6     12  6.0   11     0         0  -233.0   -2.0     268.0 -1755
# 81  BRGE7      5  8.0    5     0         0  -233.0   -2.0     268.0  -813
# 82  BRGE8      7  4.0    6     0         0  -233.0   -2.0     268.0  -986
# 84  BRIV4      7  7.0   10     0         0    21.0    8.0       6.0     8
# 86  BRKM5     24  4.0   -2    -7         0    12.0   -3.0     -16.0   -10
#
#     MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# 80   NaN   1169.0     0.0     29.0    -3.0        0.0
# 81   NaN   1169.0     0.0     14.0    -1.0        0.0
# 82   NaN   1169.0     0.0     16.0    -2.0        0.0
# 84   8.0      NaN     NaN      1.0     0.0        0.0
# 86   NaN    -15.0     NaN      0.0     3.0        0.0

# %%
# Selecionando algumas linhas, mas pulando de 2 em 2
df[0:10:2]
# Out:
#    TICKER  PRECO   DY  P/L  P/VP  P/ATIVOS  MARGEM  BRUTA  MARGEM.1  EBIT  \
# 5   AGRO3     22  4.0   11     1         1    31.0   22.0      19.0     9
# 33  BALM4     10  9.0   20     1         0    50.0    4.0       3.0    15
# 36  BBAS3     34  5.0    6     1         0    14.0    3.0      12.0    20
# 38  BBDC4     21  9.0    9     1         0    -2.0   -6.0      23.0   -34
# 45  BEES3      6  6.0    8     1         0    38.0   16.0      11.0     6
#
#     MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# 5   13.0      4.0     0.0      2.0     5.0       -1.0
# 33  21.0      3.0     0.0      1.0     2.0       -1.0
# 36  20.0      NaN     NaN      1.0     0.0        0.0
# 38 -32.0      NaN     NaN      2.0    -2.0        0.0
# 45   6.0      NaN     NaN      1.0     0.0        0.0

# %%
# Selecionando algumas linhas e colunas
df.loc[2:35, ['PRECO', 'P/L']]
# Out:
#     PRECO  P/L
# 5      22   11
# 32     13   26
# 33     10   20
# 35     37    3

# %%
df.iloc[3:5, 0:6:2]
# Out:
#    TICKER    DY  P/VP
# 35  BAZA3  11.0     0
# 36  BBAS3   5.0     1

# %%
# Formatação dos numeros, neste caso com 2 casas decimais e resolvendo o formato de notação científica
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
print(df.shape)
df = df[(df['P/L'] >= 0) & (df['P/L'] <= 25)]
df
df.describe()
# Out:
# (85, 16)
#        PRECO    DY   P/L  P/VP  P/ATIVOS  MARGEM    BRUTA  MARGEM.1     EBIT  \
# count  76.00 76.00 76.00 76.00     76.00   75.00    75.00     75.00    76.00
# mean   23.53  6.41 11.25  1.67      0.68   30.55   233.73    245.09   -35.33
# std    17.16  2.23  5.73  1.45      0.82   58.01  1776.72   1789.86   249.06
# min     3.00  4.00  3.00  0.00      0.00 -233.00    -6.00      2.00 -1755.00
# 25%    10.75  4.00  7.00  1.00      0.00   27.00     7.50     11.00     5.75
# 50%    19.50  6.00  9.00  1.00      1.00   38.00    17.00     14.00     8.00
# 75%    30.50  8.00 14.00  2.00      1.00   51.50    37.50     28.50    13.25
# max    86.00 14.00 24.00  9.00      5.00  100.00 15412.00  15530.00   122.00
#
#         MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# count  57.00    53.00   53.00    75.00   71.00      76.00
# mean   14.40    67.58    0.32    38.65   -3.35      -1.09
# std    20.67   272.39    0.67   300.55   53.61       1.32
# ...

# %%
print(df.shape)
df = df[(df['DY'] >= 5) & (df['DY'] <= 25)]
df
# Out:
# (76, 16)
#      TICKER  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM    BRUTA  MARGEM.1  \
# 33    BALM4     10  9.00   20     1         0   50.00     4.00      3.00
# 35    BAZA3     37 11.00    3     0         0   38.00    38.00     21.00
# 36    BBAS3     34  5.00    6     1         0   14.00     3.00     12.00
# 37    BBDC3     19  9.00    9     1         0   -2.00    -6.00     23.00
# 38    BBDC4     21  9.00    9     1         0   -2.00    -6.00     23.00
# 41    BBSE3     28 10.00    9     9         5     nan      nan       nan
# 45    BEES3      6  6.00    8     1         0   38.00    16.00     11.00
# 46    BEES4      6  5.00    8     1         0   38.00    16.00     11.00
# 57    BMEB4     15  5.00    5     1         0   58.00    10.00      6.00
# 58    BMGB4      6  5.00    9     1         0   66.00     2.00     10.00
# 62    BNBR3     86  6.00    4     1         0   45.00    46.00     32.00
# 80    BRGE6     12  6.00   11     0         0 -233.00    -2.00    268.00
# ...

# %%
df.describe()
# Out:
#        PRECO    DY   P/L  P/VP  P/ATIVOS  MARGEM    BRUTA  MARGEM.1     EBIT  \
# count  55.00 55.00 55.00 55.00     55.00   54.00    54.00     54.00    55.00
# mean   22.40  7.33 10.02  1.58      0.65   33.69   317.15    330.63   -34.67
# std    15.95  1.94  5.22  1.52      0.91   56.63  2093.36   2108.36   261.98
# min     3.00  5.00  3.00  0.00      0.00 -233.00    -6.00      2.00 -1755.00
# 25%    10.50  6.00  7.00  1.00      0.00   29.50     6.25     11.00     5.00
# 50%    19.00  7.00  8.00  1.00      0.00   42.00    16.50     19.00     7.00
# 75%    28.50  8.50 11.50  2.00      1.00   53.00    45.75     54.00    13.50
# max    86.00 14.00 24.00  9.00      5.00   95.00 15412.00  15530.00   122.00
#
#         MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1
# count  44.00    33.00   33.00    54.00   50.00      55.00
# mean   14.39    72.00    0.18    52.63   -2.98      -1.04
# std    23.23   282.97    0.53   354.13   61.82       1.47
# ...

# %%
# cria um novo df, com nome PagAno/DY, agora quanto de dividendos a ação paga por ano
df['PagAno/DY'] = ((df['PRECO'] / 100 )* df['DY'])

# %%
# Selecionando algumas colunas
df.loc[:, ['PRECO', 'DY', 'PagAno/DY']]
# Out:
#      PRECO    DY  PagAno/DY
# 33      10  9.00       0.90
# 35      37 11.00       4.07
# 36      34  5.00       1.70
# 37      19  9.00       1.71
# 38      21  9.00       1.89
# 41      28 10.00       2.80
# 45       6  6.00       0.36
# 46       6  5.00       0.30
# 57      15  5.00       0.75
# 58       6  5.00       0.30
# 62      86  6.00       5.16
# 80      12  6.00       0.72
# 81       5  8.00       0.40
# 84       7  7.00       0.49
# 88      10  8.00       0.80
# 91      17  6.00       1.02
# 92      23  5.00       1.15
# 93      14  7.00       0.98
# 96      55  5.00       2.75
# 112     15  5.00       0.75
# 129     33  6.00       1.98
# 130     30  6.00       1.80
# 131     29  6.00       1.74
# 134     26  7.00       1.82
# 135     26  7.00       1.82
# 153     42  9.00       3.78
# 160      6  7.00       0.42
# 164     45  7.00       3.15
# 181     25  7.00       1.75
# 209     11 10.00       1.10
# 215     50  6.00       3.00
# 246     41  5.00       2.05
# ...

# %%
# com o valor do dividendos, mostra o preço justo da ação
df['PRECO_Justo'] = (df['PagAno/DY'] * 16.67)

# %%
# Preço justo da ação
df.loc[:, ['TICKER', 'PRECO', 'DY', 'PagAno/DY', 'PRECO_Justo']]
# Out:
#      TICKER  PRECO    DY  PagAno/DY  PRECO_Justo
# 33    BALM4     10  9.00       0.90        15.00
# 35    BAZA3     37 11.00       4.07        67.85
# 36    BBAS3     34  5.00       1.70        28.34
# 37    BBDC3     19  9.00       1.71        28.51
# 38    BBDC4     21  9.00       1.89        31.51
# 41    BBSE3     28 10.00       2.80        46.68
# 45    BEES3      6  6.00       0.36         6.00
# 46    BEES4      6  5.00       0.30         5.00
# 57    BMEB4     15  5.00       0.75        12.50
# 58    BMGB4      6  5.00       0.30         5.00
# 62    BNBR3     86  6.00       5.16        86.02
# 80    BRGE6     12  6.00       0.72        12.00
# 81    BRGE7      5  8.00       0.40         6.67
# 84    BRIV4      7  7.00       0.49         8.17
# 88    BRML3     10  8.00       0.80        13.34
# 91    BRSR3     17  6.00       1.02        17.00
# 92    BRSR5     23  5.00       1.15        19.17
# 93    BRSR6     14  7.00       0.98        16.34
# ...

# %%
sns.distplot(df['DY'])

# %%
sns.distplot(df['DY'],kde=False)

# %%
ax=sns.countplot(x='DY',data=df)

# %%
sns.boxplot(x=df['DY'],orient='vertical')

# %%
print(df.shape)
df.head()
# Out:
# (55, 18)
#    TICKER  PRECO    DY  P/L  P/VP  P/ATIVOS  MARGEM  BRUTA  MARGEM.1  EBIT  \
# 33  BALM4     10  9.00   20     1         0   50.00   4.00      3.00    15
# 35  BAZA3     37 11.00    3     0         0   38.00  38.00     21.00     2
# 36  BBAS3     34  5.00    6     1         0   14.00   3.00     12.00    20
# 37  BBDC3     19  9.00    9     1         0   -2.00  -6.00     23.00   -31
# 38  BBDC4     21  9.00    9     1         0   -2.00  -6.00     23.00   -34
#
#      MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1  PagAno/DY  PRECO_Justo
# 33  21.00     3.00    0.00     1.00    2.00      -1.00       0.90        15.00
# 35   2.00      nan     nan     1.00    0.00       0.00       4.07        67.85
# 36  20.00      nan     nan     1.00    0.00       0.00       1.70        28.34
# 37 -32.00      nan     nan     2.00   -1.00       0.00       1.71        28.51
# 38 -32.00      nan     nan     2.00   -2.00       0.00       1.89        31.51

# %%
df.describe()
# Out:
#        PRECO    DY   P/L  P/VP  P/ATIVOS  MARGEM    BRUTA  MARGEM.1     EBIT  \
# count  55.00 55.00 55.00 55.00     55.00   54.00    54.00     54.00    55.00
# mean   22.40  7.33 10.02  1.58      0.65   33.69   317.15    330.63   -34.67
# std    15.95  1.94  5.22  1.52      0.91   56.63  2093.36   2108.36   261.98
# min     3.00  5.00  3.00  0.00      0.00 -233.00    -6.00      2.00 -1755.00
# 25%    10.50  6.00  7.00  1.00      0.00   29.50     6.25     11.00     5.00
# 50%    19.00  7.00  8.00  1.00      0.00   42.00    16.50     19.00     7.00
# 75%    28.50  8.50 11.50  2.00      1.00   53.00    45.75     54.00    13.50
# max    86.00 14.00 24.00  9.00      5.00   95.00 15412.00  15530.00   122.00
#
#         MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1  PagAno/DY  \
# count  44.00    33.00   33.00    54.00   50.00      55.00      55.00
# mean   14.39    72.00    0.18    52.63   -2.98      -1.04       1.61
# ...

# %%
# Out:
#        PRECO    DY   P/L  P/VP  P/ATIVOS  MARGEM    BRUTA  MARGEM.1     EBIT  \
# count  55.00 55.00 55.00 55.00     55.00   54.00    54.00     54.00    55.00
# mean   22.40  7.33 10.02  1.58      0.65   33.69   317.15    330.63   -34.67
# std    15.95  1.94  5.22  1.52      0.91   56.63  2093.36   2108.36   261.98
# min     3.00  5.00  3.00  0.00      0.00 -233.00    -6.00      2.00 -1755.00
# 25%    10.50  6.00  7.00  1.00      0.00   29.50     6.25     11.00     5.00
# 50%    19.00  7.00  8.00  1.00      0.00   42.00    16.50     19.00     7.00
# 75%    28.50  8.50 11.50  2.00      1.00   53.00    45.75     54.00    13.50
# max    86.00 14.00 24.00  9.00      5.00   95.00 15412.00  15530.00   122.00
#
#         MARG  LIQUIDA  P/EBIT  EV/EBIT  DIVIDA  LIQUIDA.1  PagAno/DY  \
# count  44.00    33.00   33.00    54.00   50.00      55.00      55.00
# mean   14.39    72.00    0.18    52.63   -2.98      -1.04       1.61
# ...
